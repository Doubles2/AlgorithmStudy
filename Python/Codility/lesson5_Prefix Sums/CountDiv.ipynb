# %%
# you can write to stdout for debugging purposes, e.g.
# print("this is a debug message")

def solution(A, B, K):
    # Implement your solution here

    cnt = 0

    if K == 1:
        return len(range(A, B+1))

    if B < K:
        if A == 0:
            cnt+=1
        return cnt
    
    if A < K and B >= K:
        if A == 0:
            cnt+=1
        A = K

    for x in range(A, B+1):
        if x < K:
            continue
        
        if x % K == 0:
            cnt+=1

    return cnt
    pass

# %%
print(solution(6, 11, 2))      # 3  -> 6, 8, 10
print(solution(0, 0, 11))      # 1  -> 0
print(solution(1, 1, 2))       # 0
print(solution(10, 10, 5))     # 1  -> 10
print(solution(10, 10, 7))     # 0
print(solution(0, 1, 11))      # 1  -> 0
print(solution(1, 10, 1))      # 10 -> 전부 가능
print(solution(1, 10, 20))     # 0
print(solution(0, 10, 5))      # 3  -> 0, 5, 10
print(solution(6, 12, 3))      # 3  -> 6, 9, 12
print(solution(7, 12, 3))      # 2  -> 9, 12
print(solution(8, 12, 3))      # 2  -> 9, 12
print(solution(9, 12, 3))      # 2  -> 9, 12
print(solution(10, 12, 3))     # 1  -> 12
print(solution(11, 12, 3))     # 1  -> 12
print(solution(12, 12, 3))     # 1  -> 12
print(solution(13, 13, 3))     # 0
print(solution(0, 100, 10))    # 11 -> 0 포함 주의
print(solution(1, 100, 10))    # 10
print(solution(0, 100, 7))     # 15 -> 0,7,...,98
print(solution(11, 345, 17))   # 20
print(solution(999999999, 1000000000, 2))  # 1 -> 1000000000
print(solution(0, 2000000000, 1))          # 2000000001
print(solution(0, 2000000000, 2000000000)) # 2 -> 0, 2000000000
# Out:
# 3
# 1
# 0
# 1
# 0
# 1
# 10
# 0
# 3
# 3
# 2
# 2
# 2
# 1
# 1
# 1
# 0
# 11
# 10
# 15
# 20
# 1
# 2000000001
# 2

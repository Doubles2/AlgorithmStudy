# %%
def solution(num):
    answer = 0
    
    if num == 1:
        return 0
    else:
        for x in range(501):
            if num == 1:
                return x
            else:
                num = num / 2 if num % 2 == 0 else num * 3 + 1
        return -1

# %%
print(solution(6))
print(solution(16))
print(solution(-626331))
# Out:
# 8
# 4
# -1

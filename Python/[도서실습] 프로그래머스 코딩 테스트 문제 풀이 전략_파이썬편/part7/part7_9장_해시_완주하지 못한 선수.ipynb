# %%
def solution(participant, completion):
    from collections import Counter

    counter_participant = Counter(participant)
    for c in completion:
        if counter_participant[c] > 0:
            counter_participant[c] -= 1
        
    answer = [x for x in counter_participant if counter_participant[x] > 0][0]
    return answer

# %%
print(solution(["leo", "kiki", "eden"],	["eden", "kiki"]))
print(solution(["marina", "josipa", "nikola", "vinko", "filipa"], ["josipa", "filipa", "marina", "nikola"]))
print(solution(["mislav", "stanko", "mislav", "ana"], ["stanko", "ana", "mislav"]))
# Out:
# Counter({'leo': 1, 'kiki': 0, 'eden': 0})
# leo
# Counter({'vinko': 1, 'marina': 0, 'josipa': 0, 'nikola': 0, 'filipa': 0})
# vinko
# Counter({'mislav': 1, 'stanko': 0, 'ana': 0})
# mislav
